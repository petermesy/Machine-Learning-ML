# %% [markdown]
# <a href="https://colab.research.google.com/github/petermesy/Machine-Learning-ML/blob/main/Understand_Your_Data_With_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pima_data=pd.read_csv('/content/indian.csv')
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
types=pima_data.dtypes
print(types)
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
pima_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin         BMI  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479   31.992578
# std       3.369578   31.972618      19.355807      15.952218  115.244002    7.884160
# min       0.000000    0.000000       0.000000       0.000000    0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000   27.300000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000   32.000000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000   36.600000
# max      17.000000  199.000000     122.000000      99.000000  846.000000   67.100000
#
#        DiabetesPedigreeFunction         Age     Outcome
# count                768.000000  768.000000  768.000000
# mean                   0.471876   33.240885    0.348958
# ...

# %%
skew=pima_data.skew()
print(skew)
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BloodPressure              -1.843608
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -0.428982
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %%
from matplotlib import pyplot
from pandas import read_csv
filename='/content/indian.csv'

data=read_csv(filename,names=names)
data = data.apply(pd.to_numeric, errors='coerce')
data.plot(kind='box',subplots=True,layout=(3,3),sharex=False,sharey=False)
pyplot.show()

# %% [markdown]
# . Multivariate Plots

# %%
from matplotlib import pyplot
from pandas import read_csv

filename = '/content/indian.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(filename, names=names)
data=data.apply(pd.to_numeric,errors='coerce')
data.plot(kind='density', subplots=True, layout=(3, 3), sharex=False)
pyplot.show()

# %%
# Class Distribution
import pandas as pd

filename = "/content/indian.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = pd.read_csv(filename, names=names)

# Class Distribution
class_counts = data.groupby('class').size()
print(class_counts)
# Out:
# class
# 0          500
# 1          268
# Outcome      1
# dtype: int64

# %%
import pandas as pd

filename = "/content/indian.csv"

column_names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']

data = pd.read_csv(filename, names=column_names, header=0)

data = data.apply(pd.to_numeric, errors='coerce')

data = data.dropna()

pd.set_option('display.width', 100)
pd.set_option('display.float_format', '{:.3f}'.format)

correlations = data.corr(method='pearson')

print(correlations)
# Out:
#         preg  plas  pres   skin   test  mass   pedi    age  class
# preg   1.000 0.129 0.141 -0.082 -0.074 0.018 -0.034  0.544  0.222
# plas   0.129 1.000 0.153  0.057  0.331 0.221  0.137  0.264  0.467
# pres   0.141 0.153 1.000  0.207  0.089 0.282  0.041  0.240  0.065
# skin  -0.082 0.057 0.207  1.000  0.437 0.393  0.184 -0.114  0.075
# test  -0.074 0.331 0.089  0.437  1.000 0.198  0.185 -0.042  0.131
# mass   0.018 0.221 0.282  0.393  0.198 1.000  0.141  0.036  0.293
# pedi  -0.034 0.137 0.041  0.184  0.185 0.141  1.000  0.034  0.174
# age    0.544 0.264 0.240 -0.114 -0.042 0.036  0.034  1.000  0.238
# class  0.222 0.467 0.065  0.075  0.131 0.293  0.174  0.238  1.000

# %% [markdown]
# The example is not generic in that it speci es the names for the attributes along the axes as
#  well as the number of ticks. This recipe cam be made more generic by removing these aspects
#  as follows:

# %%
import numpy as np
correlations=data.corr()
fig=pyplot.figure()
ax=fig.add_subplot(111)
cax=ax.matshow(correlations,vmin=-1,vmax=1)
fig.colorbar(cax)
ticks=np.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
pyplot.show()

# %% [markdown]
#  Generating the plot, you can see that it gives the same information although making it a
#  little harder to see what attributes are correlated by name. Use this generic plot as a rst cut
#  to understand the correlations in your dataset and customize it like the rst example in order
#  to read o more speci c data if needed

# %% [markdown]
# Correlation Matrix Plot (Generic)

# %%
fig=pyplot.figure()
ax=fig.add_subplot(111)
cax=ax.matshow(correlations,vmin=-1,vmax=1)
fig.colorbar(cax)
pyplot.show()

# %% [markdown]
#  6.2.2 Scatter Plot Matrix

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data)
pyplot.show()
